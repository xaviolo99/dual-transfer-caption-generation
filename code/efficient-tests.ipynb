# %%
import numpy as np
import torch
from efficientnet_pytorch import EfficientNet
from skimage.io import imread, imshow
import cv2
import time

# %%
#model = EfficientNet.from_pretrained("efficientnet-b6")
model = EfficientNet.from_pretrained("efficientnet-b4")
#model = EfficientNet.from_pretrained("efficientnet-b2")
#model = EfficientNet.from_pretrained("efficientnet-b0")
# Out:
# Loaded pretrained weights for efficientnet-b4

# %%
model = model.cuda()

# %%
#torch.cuda.memory_allocated(0)

# %%
#print(model)

# %%
image = imread("lol.jpg")

# %%
imshow(image)

# %%
#efficientnet-b0-224
#efficientnet-b1-240
#efficientnet-b2-260
#efficientnet-b3-300
#efficientnet-b4-380
#efficientnet-b5-456
#efficientnet-b6-528
#efficientnet-b7-600

image_r = cv2.resize(image, (528, 528))
#image_r = cv2.resize(image, (380, 380))
#image_r = cv2.resize(image, (260, 260))
#image_r = cv2.resize(image, (224, 224))

# %%
imshow(image_r)

# %%
img_t = torch.Tensor(image_r).cuda()
img_t = img_t.permute(2, 0, 1).unsqueeze(0)
img_t.shape
# Out:
# torch.Size([1, 3, 528, 528])

# %%
t = time.time()
for i in range(100):
    model(img_t)
print(time.time()-t)
# Out:
# 6.992403030395508

# %%
torch.cuda.memory_allocated(0)
# Out:
# 176956416
